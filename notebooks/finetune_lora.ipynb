# %% [markdown]
# # Day 4-5: LoRA fine-tune of the extraction task
#
# Colab/Kaggle GPU notebook (T4). Outline only — fill in each section as Day 4-5 work begins.
#
# 1. Load training data (`data/train/finetune_data.jsonl`): input=OCR text / output=structured JSON pairs
# 2. Load base model: `Qwen2.5-1.5B-Instruct` via `transformers` (fallback: Llama-3.2-1B/3B-Instruct if tokenizer/template issues arise)
# 3. Configure LoRA via `peft` (rank/alpha, target modules)
# 4. Wire up Weights & Biases (`wandb.init()`) and confirm a loss curve logs during training
# 5. Train
# 6. Save LoRA adapter weights (download locally or persist to Drive)
# 7. Run the fine-tuned model over the Day 3 eval set (`eval/score.py`) and compare to baseline

# %% [markdown]
# ## 1. Load training data

# %% [markdown]
# ## 2. Load base model

# %% [markdown]
# ## 3. LoRA config

# %% [markdown]
# ## 4. Weights & Biases setup

# %% [markdown]
# ## 5. Train

# %% [markdown]
# ## 6. Save adapter weights

# %% [markdown]
# ## 7. Evaluate against Day 3 eval set
